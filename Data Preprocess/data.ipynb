# %%
import pandas as pd
import numpy as np

hk_universities = ["HKU", "HKUST", "CUHK", "CityU", "PolyU", "HKBU", "LU"]


# Faculties 
hku_faculties = ["Faculty of Architecture", 
                 "Faculty of Arts", 
                 "Faculty of Business and Economics",
                 "Faculty of Dentistry", 
                 "Faculty of Education", 
                 "Faculty of Engineering", 
                 "Faculty of Law",
                 "Li Ka Shing Faculty of Medicine", 
                 "Faculty of Science", 
                 "Faculty of Social Sciences"]

## Departments-HKU
hku_faculty_of_architecture_departments = ["Department of Architecture",
                                            "Department of Real Estate and Construction"
                                            "Department of Urban Planning and Design"
                                            "Division of Landscape Architecture"]
##   
hku_faculty_of_arts_schools = ["School of Chinese",
                                "School of English",
                                "School of Humanities",
                                "School of Modern Languages and Cultures",
                                "Centre for Applied English Studies"]
        
### School of Humanities Departments
hku_department_of_school_of_humanities = ["Department of Art History",
                                          "Department of Comparative Literature",
                                          "Department of History",
                                          "Department of Linguistics",
                                          "Department of Music",
                                          "Department of Philosophy",]
###
hku_department_of_school_of_modern_languages_and_cultures = ["African Studies",
                                                             "Japanese Studies",
                                                             "American Studies",
                                                             "China Studies",
                                                             "European Studies",
                                                             "Global Creative Industries",
                                                             "Hong Kong Studies",
                                                             "Korean Studies"]
##
hku_faculty_of_business_and_economics_departments = ["Accounting and Law",
                                                     "Economics",
                                                     "Finance",
                                                     "innovation and Information Management",
                                                     "Management and Strategy",
                                                     "Marketing"]
##
hku_faculty_of_dentistry_departments = ["Dentistry"]
##
hku_faculty_of_education_departments = ["Human Communication, Learning, and Development",
                                        "Language and Literacy Education",
                                        "Mathematics, Science, and Technology",
                                        "Social Contexts and Policies of Education"]
##
hku_faculty_of_engineering_departments = ["Department of Civil Engineering",
                                          "Department of Computer Science",
                                          "Department of Electrical and Electronic Engineering",
                                          "Department of Industrial and Manufacturing Systems Engineering",
                                          "Department of Mechanical Engineering"]
##
hku_faculty_of_law_departments = ["Department of Law",
                                  "Department of Professional Legal Education",
                                  "Asian Institute of International Financial Law",
                                  "Philip K.H. Wong Centre for Chinese Law",
                                  "Centre for Comparative and Public Law",
                                  "Centre for Medical Ethics and Law",
                                  "Law and Technology Centre"]
##
hku_li_ka_shing_faculty_of_medicine_departments = ["Medicine"]
##                                         
hku_faculty_of_science_departments = ["School of Biological Sciences",
                                      "Department of Chemistry",
                                      "Department of Earth Sciences",
                                      "Department of Mathematics",
                                      "Department of Physics",
                                      "Department of Statistics and Actuarial Science"]
##
hku_faculty_of_social_science_departments = ["Department of Geography",
                                             "Department of Politics and Public Administration",
                                             "Department of Psychology",
                                             "Department of Social Work and Social Administration",
                                             "Department of Sociology",
                                             "Journalism and Media Studies Centre",
                                             "Sau Po Centre on Ageing",
                                             "Centre on Behavioral Health",
                                             "Centre for Civil Society and Governance",
                                             "Centre for Criminology",
                                             "International Center for China Development Studies",
                                             "Social Sciences Research Centre",
                                             "The Hong Kong Jockey Club Centre for Suicide Research and Prevention"]
#
hkust_faculties = ["School of Science", 
                   "School of Engineering", 
                   "School of Business and Management",
                   "School of Humanities and Social Science", 
                   "Academy of Interdisciplinary Studies"]

## Departments-HKUST
hkust_school_of_science_departments = ["Department of Chemistry",
                                       "Department of Mathematics",
                                       "Department of Ocean Science",
                                       "Department of Physics",
                                       "Division of Life Science"]
##
hkust_school_of_engineering_departments = ["Department of Chemical and Biological Engineering",
                                           "Department of Civil and Environmental Engineering",
                                           "Department of Computer Science and Engineering",
                                           "Department of Electronic and Computer Engineering",
                                           "Department of Industrial Engineering and Decision Analytics",
                                           "Department of Mechanical and Aerospace Engineering"]
##
hkust_school_of_business_and_management_departments = ["Department of Accounting",
                                                       "Department of Economics",
                                                       "Department of Finance",
                                                       "Department of Information Systems, Business Statistics and Operations Management",
                                                       "Department of Management",
                                                       "Department of Marketing"]
##
hkust_school_of_humanities_and_social_science_departments = ["Division of Humanities",
                                                             "Division of Social Science",
                                                             "Center for Language Education"]
##
hkust_academy_of_interdisciplinary_studies_departments = ["Academy of Interdisciplinary Studies",
                                                          "Division of Emerging Interdisciplinary Areas",
                                                          "Division of Environment and Sustainability",
                                                          "Division of Integrative Systems and Design",
                                                          "Division of Public Policy"]
#
cuhk_faculties = ["Faculty of Arts", 
                  "Faculty of Business Administration",
                  "Faculty of Education",
                  "Faculty of Engineering", 
                  "Faculty of Law", 
                  "Faculty of Medicine", 
                  "Faculty of Science",
                  "Faculty of Social Science"]
## Departments-CUHK
cuhk_faculty_of_arts_departments = ["Department of Anthropology",
                                        "Department of Chinese Language and Literature",
                                        "Department of Cultural and Religious Studies",
                                        "Department of English",
                                        "Department of Fine Arts",
                                        "Department of History",
                                        "Department of Japanese Studies",
                                        "Department of Linguistics and Modern Languages",
                                        "Department of Music",
                                        "Department of Philosophy",
                                        "Department of Translation",
                                        "Centre for China Studies",]
##
cuhk_faculty_of_business_administration_departments = ["The School of Accountancy",
                                                       "Department of Decisions, Operations and Technology",
                                                       "Department of Finance",
                                                       "School of Hotel and Tourism Management",
                                                       "Department of Management",
                                                       "Department of Marketing"]
##
cuhk_faculty_of_education_departments = ["Department of Curriculum and Instruction",
                                         "Department of Educational Administration and Policy",
                                         "Department of Educational Psychology",
                                         "Department of Sports Science and Physical Education"]
##
cuhk_faculty_of_engineering_departments = ["Department of Biomedical Engineering",
                                           "Department of Computer Science and Engineering",
                                           "Department of Electronic Engineering",
                                           "Department of Information Engineering",
                                           "Department of Mechanical and Automation Engineering",
                                           "Department of Systems Engineering and Engineering Management",]
##
cuhk_faculty_of_law_departments = ["Law"]
##
cuhk_faculty_of_medicine_departments = ["Department of Anaesthesia and Intensive Care",
                                        "Department of Anatomical and Cellular Pathology",
                                        "School of Biomedical Sciences",
                                        "Department of Chemical Pathology",
                                        "School of Chinese Medicine",
                                        "Department of Clinical Oncology",
                                        "Department of Imaging and Interventional Radiology",
                                        "Department of Medicine and Therapeutics",
                                        "Department of Microbiology",
                                        "The Nethersole School of Nursing",
                                        "Department of Obstetrics and Gynaecology",
                                        "Department of Ophthalmology and Visual Sciences",
                                        "Department of Orthopaedics and Traumatology",
                                        "Department of Otorhinolaryngology, Head and Neck Surgery",
                                        "Department of Paediatrics",
                                        "School of Pharmacy",
                                        "Department of Psychiatry",
                                        "The Jockey Club School of Public Health and Primary Care",
                                        "Department of Surgery"]
##
cuhk_faculty_of_science_departments = ["Department of Chemistry",
                                       "School of Life Sciences",
                                       "Department of Mathematics",
                                       "Department of Physics",
                                       "Department of Statistics",]
##
cuhk_faculty_of_social_science = ["School of Architecture",
                                  "Department of Economics",
                                  "Department of Geography and Resource Management",
                                  "Department of Government and Public Administration",
                                  "School of Journalism and Communication",
                                  "Department of Psychology",
                                  "Department of Social Work",
                                  "Department of Sociology"]
#
cityu_faculties = ["College of Business", 
                   "College of Liberal Arts and Social Sciences",
                   "Jockey Club College of Veterinary Medicine and Life Sciences", 
                   "School of Data Science",
                   "School of Law", "College of Engineering", 
                   "College of Science", "School of Creative Media",
                   "School of Energy and Environment"]
#
polyu_faculties = ["Faculty of Business", 
                   "Faculty of Construction and Environment", 
                   "Faculty of Engineering",
                   "Faculty of Health and Social Sciences", 
                   "Faculty of Humanities", 
                   "Faculty of Science",
                   "School of Design", 
                   "School of Fashion and Textiles",
                   "School of Hotel and Tourism Management"]
#
hkbu_faculties = ["Faculty of Arts", 
                  "School of Business", 
                  "School of Chinese Medicine", 
                  "School of Communication",
                  "School of Creative Arts", 
                  "Faculty of Science", 
                  "Faculty of Social Sciences",
                  "School of Continuing Education"]
#
lu_faculties = ["Faculty of Arts", 
                "Faculty of Business", 
                "Faculty of Social Sciences"]



# Links
hku_links = ["https://www.arch.hku.hk/people/arch_staff/#academic-staff",
             ["http://www.hku.hk/chinese",
              "https://english.hku.hk"],
             "https://www.hkubs.hku.hk/people",
             "https://www.scifac.hku.hk/people",
             
            ]

hkust_links = "https://facultyprofiles.hkust.edu.hk/facultylisting.php"

cuhk_links = (" ",)
cityu_links = ("https://www.cityu.edu.hk/directories/people/academic",)
polyu_links = (" ",)
hkbu_links = (" ",)
lu_links = (" ", )


uni_faculties = (hku_faculties, hkust_faculties, cuhk_faculties, cityu_faculties, polyu_faculties,
                 hkbu_faculties, lu_faculties)
uni_links = (hku_links, hkust_links, cuhk_links, cityu_links, polyu_links, hkbu_links, hkbu_links, lu_links)

df = pd.DataFrame(columns=["Schools","Faculties", "Department \ Academic Area", "Links"])
df

# %%
#hku = "https://www4.hku.hk/hkumcd/index.php/eng/unit/9_Faculty_of_Arts"

hku_departments = [[] for i in range(len(hku_faculties))]

hku_departments[0] = []

# %%
Faculties = [x for i in uni_faculties for x in i]
Schools = []
for i in range(len(uni_faculties)):
    Schools.extend([hk_universities[i]] * len(uni_faculties[i]))
print(Schools)
# Out:
# ['HKU', 'HKU', 'HKU', 'HKU', 'HKU', 'HKU', 'HKU', 'HKU', 'HKU', 'HKU', 'HKUST', 'HKUST', 'HKUST', 'HKUST', 'HKUST', 'CUHK', 'CUHK', 'CUHK', 'CUHK', 'CUHK', 'CUHK', 'CUHK', 'CUHK', 'CityU', 'CityU', 'CityU', 'CityU', 'CityU', 'CityU', 'CityU', 'CityU', 'CityU', 'PolyU', 'PolyU', 'PolyU', 'PolyU', 'PolyU', 'PolyU', 'PolyU', 'PolyU', 'PolyU', 'HKBU', 'HKBU', 'HKBU', 'HKBU', 'HKBU', 'HKBU', 'HKBU', 'HKBU', 'LU', 'LU', 'LU']

# %%
# All in one
df["Schools"] = Schools
df["Faculties"] = Faculties

df.loc[df["Schools"] == "HKUST",:].loc["Links", :] = hkust_links
df
# Out:
# <ipython-input-15-587551745c34>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df["Schools"] == "HKUST",:].loc["Links", :] = hkust_links
#    Schools                                          Faculties  \
# 0      HKU                            Faculty of Architecture
# 1      HKU                                    Faculty of Arts
# 2      HKU                  Faculty of Business and Economics
# 3      HKU                               Faculty of Dentistry
# 4      HKU                               Faculty of Education
# 5      HKU                             Faculty of Engineering
# 6      HKU                                     Faculty of Law
# 7      HKU                    Li Ka Shing Faculty of Medicine
# 8      HKU                                 Faculty of Science
# 9      HKU                         Faculty of Social Sciences
# 10   HKUST                                  School of Science
# 11   HKUST                              School of Engineering
# 12   HKUST                  School of Business and Management
# 13   HKUST            School of Humanities and Social Science
# 14   HKUST               Academy of Interdisciplinary Studies
# 15    CUHK                                    Faculty of Arts
# 16    CUHK                 Faculty of Business Administration
# 17    CUHK                               Faculty of Education
# 18    CUHK                             Faculty of Engineering
# 19    CUHK                                     Faculty of Law
# 20    CUHK                                Faculty of Medicine
# 21    CUHK                                 Faculty of Science
# 22    CUHK                          Faculty of Social Science
# 23   CityU                                College of Business
# 24   CityU        College of Liberal Arts and Social Sciences
# 25   CityU  Jockey Club College of Veterinary Medicine and...
# 26   CityU                             School of Data Science
# 27   CityU                                      School of Law
# 28   CityU                             College of Engineering
# 29   CityU                                 College of Science
# 30   CityU                           School of Creative Media
# 31   CityU                   School of Energy and Environment
# 32   PolyU                                Faculty of Business
# 33   PolyU            Faculty of Construction and Environment
# 34   PolyU                             Faculty of Engineering
# 35   PolyU              Faculty of Health and Social Sciences
# 36   PolyU                              Faculty of Humanities
# 37   PolyU                                 Faculty of Science
# 38   PolyU                                   School of Design
# 39   PolyU                     School of Fashion and Textiles
# 40   PolyU             School of Hotel and Tourism Management
# 41    HKBU                                    Faculty of Arts
# 42    HKBU                                 School of Business
# 43    HKBU                         School of Chinese Medicine
# 44    HKBU                            School of Communication
# 45    HKBU                            School of Creative Arts
# 46    HKBU                                 Faculty of Science
# 47    HKBU                         Faculty of Social Sciences
# 48    HKBU                     School of Continuing Education
# 49      LU                                    Faculty of Arts
# 50      LU                                Faculty of Business
# 51      LU                         Faculty of Social Sciences
#
#    Department \ Academic Area Links
# 0                         NaN   NaN
# 1                         NaN   NaN
# 2                         NaN   NaN
# 3                         NaN   NaN
# 4                         NaN   NaN
# 5                         NaN   NaN
# 6                         NaN   NaN
# 7                         NaN   NaN
# 8                         NaN   NaN
# 9                         NaN   NaN
# 10                        NaN   NaN
# 11                        NaN   NaN
# 12                        NaN   NaN
# 13                        NaN   NaN
# 14                        NaN   NaN
# 15                        NaN   NaN
# 16                        NaN   NaN
# 17                        NaN   NaN
# 18                        NaN   NaN
# 19                        NaN   NaN
# 20                        NaN   NaN
# 21                        NaN   NaN
# 22                        NaN   NaN
# 23                        NaN   NaN
# 24                        NaN   NaN
# 25                        NaN   NaN
# 26                        NaN   NaN
# 27                        NaN   NaN
# 28                        NaN   NaN
# 29                        NaN   NaN
# 30                        NaN   NaN
# 31                        NaN   NaN
# 32                        NaN   NaN
# 33                        NaN   NaN
# 34                        NaN   NaN
# 35                        NaN   NaN
# 36                        NaN   NaN
# 37                        NaN   NaN
# 38                        NaN   NaN
# 39                        NaN   NaN
# 40                        NaN   NaN
# 41                        NaN   NaN
# 42                        NaN   NaN
# 43                        NaN   NaN
# 44                        NaN   NaN
# 45                        NaN   NaN
# 46                        NaN   NaN
# 47                        NaN   NaN
# 48                        NaN   NaN
# 49                        NaN   NaN
# 50                        NaN   NaN
# 51                        NaN   NaN
